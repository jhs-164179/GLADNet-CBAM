# %%
import torch
from torch import nn
from torch.nn import functional as F

# %%
img = torch.rand(1, 3, 256, 256)

# %%
F.interpolate(img, size=(96,96), mode='nearest').shape
# Out:
# torch.Size([1, 3, 96, 96])
